# %% [markdown]
# # Yakup Gorur - S017327
# # Ozyegin University
# # CS 556 - BIG DATA ANALYSIS Term Project
# # 2018-2019 FALL
# # Version: PYSPARK

# %%
# Import Libraries
import numpy as np  # to handle matrix
import pandas as pd # to handle data
from matplotlib import pyplot as plt # to visualize
import datetime, pytz # to handle time
from sklearn.model_selection import train_test_split # Split data
from sklearn.ensemble import RandomForestRegressor # Random Forest Classifier

# %%
# Define a conversion function for the native timestamps in the csv file
def dateparse (time_in_secs):    
    return pytz.utc.localize(datetime.datetime.fromtimestamp(float(time_in_secs)))

# %% [markdown]
# # Import the datasets
#
# After reviewing the dataset, I decided to recode the datetime since it is better to use the dataset sorted by date not by minutes because of the dataset which I use.
# Then I group the dataset by date.

# %%
# Import the dataset and encode the date
df = pd.read_csv('coinbaseUSD.csv',parse_dates=[0], date_parser=dateparse)
df.tail(3)
# Out:
#                         Timestamp     Open     High      Low    Close  \
# 2016351 2018-11-11 02:58:00+00:00  6347.41  6347.42  6347.41  6347.42
# 2016352 2018-11-11 02:59:00+00:00  6347.41  6347.42  6347.41  6347.42
# 2016353 2018-11-11 03:00:00+00:00  6347.42  6347.42  6347.41  6347.42
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 2016351      1.213145        7700.341614     6347.418653
# 2016352      1.714091       10880.053958     6347.418881
# 2016353      0.489324        3105.944897     6347.417439

# %%
# First thing is to fix the data for bars/candles where there are no trades. 
# Volume/trades are a single event so fill "NaN"s with zeroes for relevant fields...
df['Volume_(BTC)'].fillna(value=0, inplace=True)
df['Volume_(Currency)'].fillna(value=0, inplace=True)
df['Weighted_Price'].fillna(value=0, inplace=True)

# Secondly, we need to fix the OHLC (open, high, low, close) data which is a continuous timeseries so
# let's fill forwards those values.
df['Open'].fillna(method='ffill', inplace=True)
df['High'].fillna(method='ffill', inplace=True)
df['Low'].fillna(method='ffill', inplace=True)
df['Close'].fillna(method='ffill', inplace=True)
df.tail(3)
# Out:
#                         Timestamp     Open     High      Low    Close  \
# 2016351 2018-11-11 02:58:00+00:00  6347.41  6347.42  6347.41  6347.42
# 2016352 2018-11-11 02:59:00+00:00  6347.41  6347.42  6347.41  6347.42
# 2016353 2018-11-11 03:00:00+00:00  6347.42  6347.42  6347.41  6347.42
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 2016351      1.213145        7700.341614     6347.418653
# 2016352      1.714091       10880.053958     6347.418881
# 2016353      0.489324        3105.944897     6347.417439

# %%
# Indicate the 'start' and 'end' time. [To beginning to the end. (END can be change according to today's date)]
start = datetime.datetime(2009, 1, 1, 0, 0, 0, 0, pytz.UTC)
end = datetime.datetime(2020, 10, 17, 20, 0, 0, 0, pytz.UTC)

# find rows between start and end time and find the first row (00:00 monday morning)
# Grouping by day
daily_df = df[(df['Timestamp'] >= start) & (df['Timestamp'] <= end)].groupby([pd.Grouper(key='Timestamp', freq='D')]).first().reset_index()
daily_df = daily_df.set_index('Timestamp')
daily_df.tail(3)
# Out:
#                               Open     High      Low    Close  Volume_(BTC)  \
# Timestamp
# 2018-11-09 00:00:00+00:00  6419.05  6419.06  6419.05  6419.06      0.939389
# 2018-11-10 00:00:00+00:00  6342.06  6342.07  6342.06  6342.07      2.075609
# 2018-11-11 00:00:00+00:00  6365.00  6365.00  6364.99  6364.99      1.044918
#
#                            Volume_(Currency)  Weighted_Price
# Timestamp
# 2018-11-09 00:00:00+00:00        6029.991228     6419.054827
# 2018-11-10 00:00:00+00:00       13163.654823     6342.067698
# 2018-11-11 00:00:00+00:00        6650.897185     6364.992297

# %%
# Again fill NaN
daily_df['Volume_(BTC)'].fillna(value=0, inplace=True)
daily_df['Volume_(Currency)'].fillna(value=0, inplace=True)
daily_df['Weighted_Price'].fillna(value=0, inplace=True)

daily_df['Open'].fillna(method='ffill', inplace=True)
daily_df['High'].fillna(method='ffill', inplace=True)
daily_df['Low'].fillna(method='ffill', inplace=True)
daily_df['Close'].fillna(method='ffill', inplace=True)

print("Shape: ", daily_df.shape)
print("Columns= ", daily_df.columns)
print("Is There any 'NaN' value: ", daily_df.isnull().values.any())
print("Is there any duplicate value: ", daily_df.index.duplicated().any())
daily_df.tail(3)
# Out:
# Shape:  (1442, 7)
# Columns=  Index(['Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)',
#        'Weighted_Price'],
#       dtype='object')
# Is There any 'NaN' value:  False
# Is there any duplicate value:  False
#                               Open     High      Low    Close  Volume_(BTC)  \
# Timestamp
# 2018-11-09 00:00:00+00:00  6419.05  6419.06  6419.05  6419.06      0.939389
# 2018-11-10 00:00:00+00:00  6342.06  6342.07  6342.06  6342.07      2.075609
# 2018-11-11 00:00:00+00:00  6365.00  6365.00  6364.99  6364.99      1.044918
#
#                            Volume_(Currency)  Weighted_Price
# Timestamp
# 2018-11-09 00:00:00+00:00        6029.991228     6419.054827
# 2018-11-10 00:00:00+00:00       13163.654823     6342.067698
# 2018-11-11 00:00:00+00:00        6650.897185     6364.992297

# %% [markdown]
# # Add historical data

# %%
historical_df = daily_df
for i in range(1,8): # for 7 days
    historical_df["Open_b_"+str(i)] = daily_df['Open'].shift(i)
    historical_df["High_b_"+str(i)] = daily_df['High'].shift(i)
    historical_df["Low_b_"+str(i)]  = daily_df['Low'].shift(i)
    historical_df["Close_b_"+str(i)]= daily_df['Close'].shift(i)
    historical_df["Volume_(BTC)_b_"+str(i)]      = daily_df['Volume_(BTC)'].shift(i)
    historical_df["Volume_(Currency)_b_"+str(i)] = daily_df['Volume_(Currency)'].shift(i)

historical_df = historical_df.dropna() # drop the first rows. They don't have previous information 
print("Historical Data Shape: ", historical_df.shape)
historical_df.tail(3)
# Out:
# Historical Data Shape:  (1435, 49)
#                               Open     High      Low    Close  Volume_(BTC)  \
# Timestamp
# 2018-11-09 00:00:00+00:00  6419.05  6419.06  6419.05  6419.06      0.939389
# 2018-11-10 00:00:00+00:00  6342.06  6342.07  6342.06  6342.07      2.075609
# 2018-11-11 00:00:00+00:00  6365.00  6365.00  6364.99  6364.99      1.044918
#
#                            Volume_(Currency)  Weighted_Price  Open_b_1  \
# Timestamp
# 2018-11-09 00:00:00+00:00        6029.991228     6419.054827   6506.99
# 2018-11-10 00:00:00+00:00       13163.654823     6342.067698   6419.05
# 2018-11-11 00:00:00+00:00        6650.897185     6364.992297   6342.06
#
#                            High_b_1  Low_b_1          ...            Low_b_6  \
# Timestamp                                             ...
# 2018-11-09 00:00:00+00:00   6507.00  6506.68          ...            6350.55
# 2018-11-10 00:00:00+00:00   6419.06  6419.05          ...            6339.99
# 2018-11-11 00:00:00+00:00   6342.07  6342.06          ...            6411.40
#
#                            Close_b_6  Volume_(BTC)_b_6  Volume_(Currency)_b_6  \
# Timestamp
# 2018-11-09 00:00:00+00:00    6352.35          3.163061           20090.158335
# 2018-11-10 00:00:00+00:00    6339.99          1.239509            7858.480515
# 2018-11-11 00:00:00+00:00    6413.00          0.469015            3007.588594
#
#                            Open_b_7  High_b_7  Low_b_7  Close_b_7  \
# Timestamp
# 2018-11-09 00:00:00+00:00   6337.24   6337.24  6337.23    6337.24
# 2018-11-10 00:00:00+00:00   6352.09   6353.03  6350.55    6352.35
# 2018-11-11 00:00:00+00:00   6340.00   6340.00  6339.99    6339.99
#
#                            Volume_(BTC)_b_7  Volume_(Currency)_b_7
# Timestamp
# 2018-11-09 00:00:00+00:00          0.805539            5104.892169
# 2018-11-10 00:00:00+00:00          3.163061           20090.158335
# 2018-11-11 00:00:00+00:00          1.239509            7858.480515
#
# [3 rows x 49 columns]

# %% [markdown]
# # Add Label

# %%
historical_df["NEXT_CLOSE"] = historical_df['Close'].shift(-1) # Add next data as a label for current data
historical_df = historical_df.dropna() # drop the last row. It doesn't have next information 
print("after adding next CLOSE Label, new shape:", historical_df.shape)
historical_df.tail(3)
# Out:
# after adding next CLOSE Label, new shape: (1434, 50)
# /Users/yakup/anaconda3/envs/yakup3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                               Open     High      Low    Close  Volume_(BTC)  \
# Timestamp
# 2018-11-08 00:00:00+00:00  6506.99  6507.00  6506.68  6506.69      1.478680
# 2018-11-09 00:00:00+00:00  6419.05  6419.06  6419.05  6419.06      0.939389
# 2018-11-10 00:00:00+00:00  6342.06  6342.07  6342.06  6342.07      2.075609
#
#                            Volume_(Currency)  Weighted_Price  Open_b_1  \
# Timestamp
# 2018-11-08 00:00:00+00:00        9621.757571     6506.989100   6418.55
# 2018-11-09 00:00:00+00:00        6029.991228     6419.054827   6506.99
# 2018-11-10 00:00:00+00:00       13163.654823     6342.067698   6419.05
#
#                            High_b_1  Low_b_1     ...      Close_b_6  \
# Timestamp                                        ...
# 2018-11-08 00:00:00+00:00   6418.55  6418.54     ...        6337.24
# 2018-11-09 00:00:00+00:00   6507.00  6506.68     ...        6352.35
# 2018-11-10 00:00:00+00:00   6419.06  6419.05     ...        6339.99
#
#                            Volume_(BTC)_b_6  Volume_(Currency)_b_6  Open_b_7  \
# Timestamp
# 2018-11-08 00:00:00+00:00          0.805539            5104.892169   6301.00
# 2018-11-09 00:00:00+00:00          3.163061           20090.158335   6337.24
# 2018-11-10 00:00:00+00:00          1.239509            7858.480515   6352.09
#
#                            High_b_7  Low_b_7  Close_b_7  Volume_(BTC)_b_7  \
# Timestamp
# 2018-11-08 00:00:00+00:00   6301.00  6300.38    6300.44          1.897522
# 2018-11-09 00:00:00+00:00   6337.24  6337.23    6337.24          0.805539
# 2018-11-10 00:00:00+00:00   6353.03  6350.55    6352.35          3.163061
#
#                            Volume_(Currency)_b_7  NEXT_CLOSE
# Timestamp
# 2018-11-08 00:00:00+00:00           11955.590221     6419.06
# 2018-11-09 00:00:00+00:00            5104.892169     6342.07
# 2018-11-10 00:00:00+00:00           20090.158335     6364.99
#
# [3 rows x 50 columns]

# %% [markdown]
# # Split Data and set the test/train data and their's labels

# %%
# split data
prediction_days = 140
df_train = historical_df[:len(historical_df) - prediction_days ]
df_test  = historical_df[ len(historical_df) - prediction_days:]

print("PERCENT test/total data = %", (prediction_days/len(historical_df)) * 100)
print("train data shape:", df_train.shape)
print("test data shape:", df_test.shape)
df_train.head(3)
# Out:
# PERCENT test/total data = % 9.762900976290098
# train data shape: (1294, 50)
# test data shape: (140, 50)
#                              Open    High    Low  Close  Volume_(BTC)  \
# Timestamp
# 2014-12-08 00:00:00+00:00  378.00  378.00  378.0  378.0         0.000
# 2014-12-09 00:00:00+00:00  375.01  375.01  375.0  375.0         0.235
# 2014-12-10 00:00:00+00:00  398.00  398.00  398.0  398.0         0.010
#
#                            Volume_(Currency)  Weighted_Price  Open_b_1  \
# Timestamp
# 2014-12-08 00:00:00+00:00             0.0000        0.000000    378.00
# 2014-12-09 00:00:00+00:00            88.1251      375.000426    378.00
# 2014-12-10 00:00:00+00:00             3.9800      398.000000    375.01
#
#                            High_b_1  Low_b_1     ...      Close_b_6  \
# Timestamp                                        ...
# 2014-12-08 00:00:00+00:00    378.00    378.0     ...         370.00
# 2014-12-09 00:00:00+00:00    378.00    378.0     ...         378.00
# 2014-12-10 00:00:00+00:00    375.01    375.0     ...         377.01
#
#                            Volume_(BTC)_b_6  Volume_(Currency)_b_6  Open_b_7  \
# Timestamp
# 2014-12-08 00:00:00+00:00               0.0                    0.0     300.0
# 2014-12-09 00:00:00+00:00               0.0                    0.0     370.0
# 2014-12-10 00:00:00+00:00               0.0                    0.0     378.0
#
#                            High_b_7  Low_b_7  Close_b_7  Volume_(BTC)_b_7  \
# Timestamp
# 2014-12-08 00:00:00+00:00     300.0    300.0      300.0              0.01
# 2014-12-09 00:00:00+00:00     370.0    370.0      370.0              0.00
# 2014-12-10 00:00:00+00:00     378.0    378.0      378.0              0.00
#
#                            Volume_(Currency)_b_7  NEXT_CLOSE
# Timestamp
# 2014-12-08 00:00:00+00:00                    3.0       375.0
# 2014-12-09 00:00:00+00:00                    0.0       398.0
# 2014-12-10 00:00:00+00:00                    0.0       398.0
#
# [3 rows x 50 columns]

# %% [markdown]
# # Pyspark

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
sc = SparkContext('local')
spark = SparkSession(sc)

# %%
spark_TrainingData = spark.createDataFrame(df_train)
spark_TestData =  spark.createDataFrame(df_test)

# %%
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.linalg import Vectors

transformed_TrainingData = spark_TrainingData.rdd.map(lambda row: LabeledPoint(row[-1], Vectors.dense(row[0:-1])))
transformed_TestData = spark_TestData.rdd.map(lambda row: LabeledPoint(row[-1], Vectors.dense(row[0:-1])))

# %%
print("Number of training set rows: %d" % transformed_TrainingData.count())
print("Number of test set rows: %d" % transformed_TestData.count())
# Out:
# Number of training set rows: 1294
# Number of test set rows: 140

# %%
# Let's make sure we have the correct types.
print("%s should be an RDD" % type(transformed_TrainingData))
print("%s should be a LabeledPoint" % type(transformed_TestData.first()))
# Out:
# <class 'pyspark.rdd.PipelinedRDD'> should be an RDD
# <class 'pyspark.mllib.regression.LabeledPoint'> should be a LabeledPoint

# %% [markdown]
# # Train the random forest model

# %%
from pyspark.mllib.tree import RandomForest
from time import *
RF_NUM_TREES = 20 # 5
RF_MAX_DEPTH = 7 # 5
IMPURITY ="variance"
RF_MAX_BINS = 300
RANDOM_SEED = 13579 #None

start_time = time()

model = RandomForest.trainRegressor(transformed_TrainingData, categoricalFeaturesInfo={}, \
    numTrees=RF_NUM_TREES, featureSubsetStrategy="auto", impurity= IMPURITY, \
    maxDepth=RF_MAX_DEPTH, maxBins=RF_MAX_BINS, seed=RANDOM_SEED)

end_time = time()
elapsed_time = end_time - start_time
print("Time to train model: %.3f seconds" % elapsed_time)
# Out:
# Time to train model: 12.287 seconds

# %%
from pyspark.mllib.tree import RandomForest
from time import *
RF_NUM_TREES = 1000 # 5
RF_MAX_DEPTH = 7 # 5
IMPURITY ="variance"
RF_MAX_BINS = 300
RANDOM_SEED = 13579 #None

start_time = time()

model = RandomForest.trainRegressor(transformed_TrainingData, categoricalFeaturesInfo={}, \
    numTrees=RF_NUM_TREES, featureSubsetStrategy="auto", impurity= IMPURITY, \
    maxDepth=RF_MAX_DEPTH, maxBins=RF_MAX_BINS, seed=RANDOM_SEED)

end_time = time()
elapsed_time = end_time - start_time
print("Time to train model: %.3f seconds" % elapsed_time)
# Out:
# Time to train model: 347.676 seconds

# %% [markdown]
# # Make predictions and compute accuracy

# %%
# Make predictions
predictions = model.predict(transformed_TestData.map(lambda x: x.features))
reals_and_predictions = transformed_TestData.map(lambda x: x.label).zip(predictions)

# %%
# compute accuracy
from pyspark.mllib.evaluation import RegressionMetrics

start_time = time()

metrics = RegressionMetrics(reals_and_predictions)
print("Root Mean Squared Error: %.f" % (metrics.rootMeanSquaredError))
print("R^2 Error: %.3f" % (metrics.r2))

end_time = time()
elapsed_time = end_time - start_time
print("Time to evaluate model: %.3f seconds" % elapsed_time)
# Out:
# Root Mean Squared Error: 193
# R^2 Error: 0.822
# Time to evaluate model: 3.830 seconds

# %% [markdown]
# # Visualising the results

# %%
list_Real = transformed_TestData.map(lambda x: x.label).collect()
list_Predicted = predictions.collect()

# %%
# Visualising the results
plt.figure(figsize=(25,15), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.plot(df_test.index,list_Real, color = 'red', label = 'Real BTC Price')
plt.plot(df_test.index,list_Predicted, color = 'blue', label = 'Predicted BTC Price')
plt.title('BTC Price Prediction', fontsize=40)
x = df_test.reset_index().index
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
plt.xlabel('Time', fontsize=40)
plt.ylabel('BTC Price(USD) [Closed]', fontsize=40)
plt.legend(loc=2, prop={'size': 25})
plt.show()
